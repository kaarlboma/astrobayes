# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load beta samples
df = pd.read_csv("beta_samples.csv", header=None)
df.columns = [f'beta_{i}' for i in range(df.shape[1])]

# Plot histograms
df.plot(kind='hist', bins=50, alpha=0.7, subplots=True, layout=(df.shape[1], 1), figsize=(8, 2*df.shape[1]), legend=False)
plt.tight_layout()
plt.show()

# %%
df
# Out:
#         beta_0    beta_1    beta_2    beta_3    beta_4    beta_5    beta_6
# 0     2.467214  0.001565 -0.001518  0.003222  9.082660  0.004833  1.646414
# 1     0.817492  0.001390 -0.000753  0.003189  6.825836  0.003421  3.058781
# 2    -1.327843  0.001426  0.000054  0.003520  3.913784  0.004238  3.159598
# 3     1.002626  0.001287 -0.001104  0.003212  8.368056  0.004414  2.743846
# 4     1.440200  0.001279 -0.001350  0.003687  8.819327  0.004016  2.076165
# ...        ...       ...       ...       ...       ...       ...       ...
# 4995  2.548944  0.001471 -0.001094  0.002772  7.125116  0.004764  1.668631
# 4996  2.094077  0.001582 -0.001383  0.003371  8.718005  0.004085  1.847524
# 4997  1.044322  0.001473 -0.000965  0.003620  6.752918  0.005066  2.270211
# 4998  0.886785  0.001470 -0.000756  0.003360  6.742288  0.003608  2.153828
# 4999  1.320331  0.001260 -0.001093  0.003582  7.801172  0.003659  1.908444
#
# [5000 rows x 7 columns]
